# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\bhatn\Desktop\data science upflairs\Data-Science-AI-and-ML\Pandas\laptopPrice.csv')

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates(inplace=True)

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
char = df.select_dtypes(include='object')

# %%
char
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
num = df.select_dtypes(exclude='object')

# %%
num
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [802 rows x 3 columns]

# %%
df['brand'].nunique()
# Out:
# 8

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
char['brand'] = le.fit_transform(char['brand'])

# %%
char['brand'].unique()
# Out:
# array([1, 5, 7, 2, 4, 3, 6, 0])

# %%
char
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0        1           Intel        Core i3            10th   4 GB     DDR4
# 1        5           Intel        Core i3            10th   4 GB     DDR4
# 2        5           Intel        Core i3            10th   4 GB     DDR4
# 3        1           Intel        Core i5            10th   8 GB     DDR4
# 4        1           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...             ...            ...             ...    ...      ...
# 818      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822      5             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
char['processor_brand'] = le.fit_transform(char['processor_brand'])

# %%
char['processor_brand'].unique()
# Out:
# array([1, 0, 2])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
char['processor_name'] = le.fit_transform(char['processor_name'])

# %%
char['processor_name'].unique()
# Out:
# array([ 1,  2,  0,  8,  3,  4,  5,  6,  7,  9, 10])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
char['processor_gnrtn']= le.fit_transform(char['processor_gnrtn'])

# %%
char['processor_gnrtn'].unique()
# Out:
# array([0, 7, 1, 4, 5, 6, 3, 2])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
char['ram_gb']= le.fit_transform(char['ram_gb'])

# %%
char['ram_gb'].unique()
# Out:
# array([2, 3, 0, 1])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
char['ram_type'] = le.fit_transform(char['ram_type'])

# %%
char['ram_type'].unique()
# Out:
# array([1, 4, 5, 2, 0, 3])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
char['ssd'] = le.fit_transform(char['ssd'])

# %%
char['ssd'].unique()
# Out:
# array([0, 6, 4, 2, 1, 3, 5])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
char['hdd']= le.fit_transform(char['hdd'])

# %%
char['hdd'].unique()
# Out:
# array([1, 0, 3, 2])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
char['os']= le.fit_transform(char['os'])
char['os_bit']= le.fit_transform(char['os_bit'])
char['graphic_card_gb']= le.fit_transform(char['graphic_card_gb'])
char['weight']= le.fit_transform(char['weight'])
char['warranty']= le.fit_transform(char['warranty'])
char['Touchscreen']= le.fit_transform(char['Touchscreen'])
char['msoffice']= le.fit_transform(char['msoffice'])
char['rating']= le.fit_transform(char['rating'])

# %%
char
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                0       2
# 1        5                1               1                0       2
# 2        5                1               1                0       2
# 3        1                1               2                0       3
# 4        1                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      1                0              10                7       2
# 819      1                0              10                7       2
# 820      1                0              10                7       2
# 821      1                0              10                7       2
# 822      5                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
num
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [802 rows x 3 columns]

# %%
clean_data = pd.concat([char,num],axis=1)

# %%
clean_data
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                0       2
# 1        5                1               1                0       2
# 2        5                1               1                0       2
# 3        1                1               2                0       3
# 4        1                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      1                0              10                7       2
# 819      1                0              10                7       2
# 820      1                0              10                7       2
# 821      1                0              10                7       2
# 822      5                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
clean_data.to_csv('cleaned_laptop.csv')

# %%
x = clean_data.drop('Price' , axis =1)

# %%
y = clean_data[['Price']]

# %%
x
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                0       2
# 1        5                1               1                0       2
# 2        5                1               1                0       2
# 3        1                1               2                0       3
# 4        1                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      1                0              10                7       2
# 819      1                0              10                7       2
# 820      1                0              10                7       2
# 821      1                0              10                7       2
# 822      5                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
y
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [802 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test ,y_train ,y_test =train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((641, 18), (161, 18), (641, 1), (161, 1))

# %%
from sklearn.linear_model import LinearRegression

Lr = LinearRegression()
Lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
Lr.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
Lr.score(x_train, y_train)
# Out:
# 0.5836964629683771

# %%
pred = Lr.predict(x_test)

# %%
pred =pd.DataFrame(pred)

# %%
y_test
# Out:
#       Price
# 196   50990
# 299   72990
# 171   41490
# 537  144690
# 551  129990
# ..      ...
# 368  114990
# 361  126000
# 446   57990
# 767  106990
# 529  110999
#
# [161 rows x 1 columns]

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train, y_train)
# Out:
# c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
pred =svr.predict(x_test)

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 196      7                1               2                7       3
# 299      1                1               2                1       3
# 171      3                1               1                0       3
# 537      4                1               3                0       0
# 551      6                1               3                1       0
# ..     ...              ...             ...              ...     ...
# 368      1                1               2                1       3
# 361      4                1               2                0       3
# 446      3                1               2                1       3
# 767      5                0               9                7       2
# 529      5                1               3                1       0
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
dt =DecisionTreeRegressor()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(x_train, y_train)
# Out:
# 0.998034456706054

# %%
pred =dt.predict(x_test)

# %%
red =pd.DataFrame(pred)

# %%
y_test
# Out:
#       Price
# 196   50990
# 299   72990
# 171   41490
# 537  144690
# 551  129990
# ..      ...
# 368  114990
# 361  126000
# 446   57990
# 767  106990
# 529  110999
#
# [161 rows x 1 columns]

# %%
from sklearn.datasets import load_iris
x,y = load_iris(return_X_y=True)
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn.fit(x_train , y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
knn.predict(x_test)
# Out:
# array([[ 47130. ],
#        [ 63990. ],
#        [ 63074. ],
#        [ 69928. ],
#        [ 75350. ],
#        [131188. ],
#        [ 47530. ],
#        [ 70895.6],
#        [ 72270. ],
#        [ 90076.2],
#        [ 46172. ],
#        [ 72070. ],
#        [ 71844.2],
#        [118694. ],
#        [ 53790. ],
#        [ 88233.4],
#        [ 74653.8],
#        [ 64774. ],
#        [ 64993.6],
#        [136383. ],
#        [ 56670. ],
#        [ 53213.8],
#        [ 79773.8],
#        [ 65939.6],
#        [ 35190. ],
#        [ 54590. ],
#        [ 60290. ],
#        [172591.6],
#        [ 72165.4],
#        [ 63767.4],
#        [ 54551.8],
#        [ 72492. ],
#        [ 52992.2],
#        [ 89555.6],
#        [ 67033.6],
#        [ 54782. ],
#        [121090. ],
#        [ 64391.8],
#        [ 58831.8],
#        [ 67490. ],
#        [ 56670. ],
#        [ 69990. ],
#        [ 53790. ],
#        [ 39288. ],
#        [ 79272. ],
#        [ 67193.6],
#        [ 63750. ],
# ...

# %%
x_train
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 442      1                1               2                1       3
# 598      1                1               3                0       0
# 452      1                1               2                1       3
# 696      3                0               8                7       3
# 339      1                1               2                1       3
# ..     ...              ...             ...              ...     ...
# 73       5                1               1                0       2
# 108      3                1               1                1       3
# 275      5                1               2                0       3
# 445      1                1               2                1       3
# 104      1                1               1                1       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
# Using RandomForestRegressor for regression tasks

# Rfc = RandomForestClassifier()
Rfr=RandomForestRegressor()
Rfr.fit(x_train , y_train)
# Rfc.fit(x_train , y_train)
# Out:
# c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
from sklearn.metrics import classification_report,precision_score,recall_score,confusion_matrix,f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
df = DecisionTreeRegressor()
df.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
df.score(x_test, y_test)
# Out:
# 0.5150266521669131

# %%
pred = df.predict(x_test)
