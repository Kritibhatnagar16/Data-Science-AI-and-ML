# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\bhatn\Desktop\data science upflairs\Data-Science-AI-and-ML\Projects\Insurance\insurance dataset.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
char = df.select_dtypes(include='object')

# %%
char
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1337 rows x 3 columns]

# %%
num = df.select_dtypes(exclude=['object'])

# %%
num
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1337 rows x 4 columns]

# %%
df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder  
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

# %%
df['sex'].unique()
# Out:
# array([0, 1])

# %%
df['smoker'].unique()
# Out:
# array([1, 0])

# %%
df['region'].unique()
# Out:
# array([3, 2, 1, 0])

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1337 rows x 7 columns]

# %%
x = df.drop('charges', axis=1)
y = df['charges']

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1337 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1337, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1069, 6), (268, 6), (1069,), (268,))

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor() 
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model.score(x_test, y_test)
# Out:
# 0.7748470099041644

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()  
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.8068466322629111

# %%
from sklearn.datasets import load_iris
x,y = load_iris(return_X_y=True)
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
from sklearn.svm import SVR
model = SVR()
model.fit(x_train, y_train)
# Out:
# SVR()

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor()   
model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor() 
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.metrics import classification_report,precision_score,recall_score,confusion_matrix,f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
df = DecisionTreeRegressor()
df.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
#        24535.69855,  8605.3615 ,  5002.7827 ,  7986.47525, 13012.20865,
#         1631.8212 ,  2166.732  ,  7518.02535,  8444.474  ,  2205.9808 ,
#         3385.39915, 45702.02235, 48885.13561, 16455.70785,  9386.1613 ,
#        46599.1084 , 41919.097  ,  9264.797  , 36219.40545,  4243.59005,
#        13470.8044 , 36837.467  ,  3537.703  ,  5969.723  , 11931.12525,
#        21232.18226, 13012.20865,  1631.6683 ,  3201.24515,  3392.3652 ,
#         4504.6624 ,  2523.1695 ,  4040.55825,  9861.025  ,  1632.56445,
#         9855.1314 ,  3847.674  ,  6356.2707 ,  2200.83085,  8116.26885,
#         2709.24395, 11658.37915, 12233.828  , 13430.265  , 44641.1974 ,
#        14283.4594 , 11454.0215 , 18804.7524 ,  8017.06115, 10600.5483 ,
#        36219.40545, 46599.1084 , 11987.1682 , 14901.5167 , 13887.9685 ,
#         4466.6214 , 48517.56315, 11520.09985])

# %%
print(classification_report(y_test,pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 print(classification_report(y_test,pred))
#
# File c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:2948, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2840 """Build a text report showing the main classification metrics.
#    2841
#    2842 Read more in the :ref:`User Guide <classification_report>`.
#    (...)   2944 <BLANKLINE>
#    2945 """
#    2947 y_true, y_pred = attach_unique(y_true, y_pred)
# -> 2948 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2950 if labels is None:
#    2951     labels = unique_labels(y_true, y_pred)
#
# File c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:117, in _check_targets(y_true, y_pred)
#     115 # No metrics support "multiclass-multioutput" format
#     116 if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 117     raise ValueError("{0} is not supported".format(y_type))
#     119 if y_type in ["binary", "multiclass"]:
#     120     xp, _ = get_namespace(y_true, y_pred)
#
# ValueError: continuous is not supported

# %%
print(precision_score(y_test,pred))
print(recall_score(y_test,pred))
print(f1_score(y_test,pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 print(precision_score(y_test,pred))
#       2 print(recall_score(y_test,pred))
#       3 print(f1_score(y_test,pred))
#
# File c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:2524, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2356 @validate_params(
#    2357     {
#    2358         "y_true": ["array-like", "sparse matrix"],
#    (...)   2383     zero_division="warn",
#    2384 ):
#    2385     """Compute the precision.
#    2386
#    2387     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)   2522     array([0.5, 1. , 1. ])
#    2523     """
# -> 2524     p, _, _, _ = precision_recall_fscore_support(
#    2525         y_true,
#    2526         y_pred,
#    2527         labels=labels,
#    2528         pos_label=pos_label,
#    2529         average=average,
#    2530         warn_for=("precision",),
#    2531         sample_weight=sample_weight,
#    2532         zero_division=zero_division,
#    2533     )
#    2534     return p
#
# File c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1996, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1827 """Compute precision, recall, F-measure and support for each class.
#    1828
#    1829 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)   1993  array([2, 2, 2]))
#    1994 """
#    1995 _check_zero_division(zero_division)
# -> 1996 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1998 # Calculate tp_sum, pred_sum, true_sum ###
#    1999 samplewise = average == "samples"
#
# File c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1762, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1759     raise ValueError("average has to be one of " + str(average_options))
#    1761 y_true, y_pred = attach_unique(y_true, y_pred)
# -> 1762 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1763 # Convert to Python primitive type to avoid NumPy type / Python str
#    1764 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1765 present_labels = _tolist(unique_labels(y_true, y_pred))
#
# File c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:117, in _check_targets(y_true, y_pred)
#     115 # No metrics support "multiclass-multioutput" format
#     116 if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 117     raise ValueError("{0} is not supported".format(y_type))
#     119 if y_type in ["binary", "multiclass"]:
#     120     xp, _ = get_namespace(y_true, y_pred)
#
# ValueError: continuous is not supported
