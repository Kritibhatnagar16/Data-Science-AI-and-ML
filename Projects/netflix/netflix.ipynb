# %%
import pandas as pd

# %%
df = pd.read_csv('Netflix.csv')

# %%
df
# Out:
#     show_id     type                                 title         director  \
# 0        s1    Movie                  Dick Johnson Is Dead  Kirsten Johnson
# 1        s2  TV Show                         Blood & Water              NaN
# 2        s3  TV Show                             Ganglands  Julien Leclercq
# 3        s4  TV Show                 Jailbirds New Orleans              NaN
# 4        s5  TV Show                          Kota Factory              NaN
# ..      ...      ...                                   ...              ...
# 195    s196    Movie       EMI: Liya Hai To Chukana Padega    Saurabh Kabra
# 196    s197    Movie                         He's All That      Mark Waters
# 197    s198  TV Show                          I Heart Arlo              NaN
# 198    s199  TV Show  King of Boys: The Return of the King     Kemi Adetiba
# 199    s200    Movie                            Koi Aap Sa     Partho Mitra
#
#                                                   cast        country  \
# 0                                                  NaN  United States
# 1    Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2    Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                  NaN            NaN
# 4    Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ..                                                 ...            ...
# 195  Sanjay Dutt, Arjun Rampal, Malaika Arora, Aash...          India
# 196  Addison Rae, Tanner Buchanan, Rachael Leigh Co...            NaN
# 197  Michael J. Woodard, Mary Lambert, Jonathan Van...            NaN
# 198  Sola Sobowale, Toni Tones, Richard Mofe-Damijo...        Nigeria
# 199  Aftab Shivdasani, Natassha, Dipannita Sharma, ...          India
#
#     date_added  release_year rating   duration  \
# 0    25-Sep-21          2020  PG-13     90 min
# 1    24-Sep-21          2021  TV-MA  2 Seasons
# 2    24-Sep-21          2021  TV-MA   1 Season
# 3    24-Sep-21          2021  TV-MA   1 Season
# 4    24-Sep-21          2021  TV-MA  2 Seasons
# ..         ...           ...    ...        ...
# 195  27-Aug-21          2008  TV-14    128 min
# 196  27-Aug-21          2021  TV-14     92 min
# 197  27-Aug-21          2021  TV-Y7   1 Season
# 198  27-Aug-21          2021  TV-MA   1 Season
# 199  27-Aug-21          2006  TV-14    135 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 1      International TV Shows, TV Dramas, TV Mysteries
# 2    Crime TV Shows, International TV Shows, TV Act...
# 3                               Docuseries, Reality TV
# 4    International TV Shows, Romantic TV Shows, TV ...
# ..                                                 ...
# 195             Comedies, Dramas, International Movies
# 196                          Comedies, Romantic Movies
# 197                              Kids' TV, TV Comedies
# 198  Crime TV Shows, International TV Shows, TV Dramas
# 199             Comedies, Dramas, International Movies
#
#                                            description
# 0    As her father nears the end of his life, filmm...
# 1    After crossing paths at a party, a Cape Town t...
# 2    To protect his family from a powerful drug lor...
# 3    Feuds, flirtations and toilet talk go down amo...
# 4    In a city of coaching centers known to train I...
# ..                                                 ...
# 195  A bank hires an enigmatic and unorthodox debt ...
# 196  An influencer specializing in makeovers bets s...
# 197  It's a whole new world for Arlo and his one-of...
# 198  Alhaja Eniola Salami starts anew and sets her ...
# 199  Star athlete Rohan has his eye on a beautiful ...
#
# [200 rows x 12 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     show_id     type                                 title  \
# 7        s8    Movie                               Sankofa
# 8        s9  TV Show         The Great British Baking Show
# 9       s10    Movie                          The Starling
# 12      s13    Movie                          Je Suis Karl
# 24      s25    Movie                                 Jeans
# ..      ...      ...                                   ...
# 191    s192    Movie                            Wind River
# 192    s193    Movie                            C Kkompany
# 195    s196    Movie       EMI: Liya Hai To Chukana Padega
# 198    s199  TV Show  King of Boys: The Return of the King
# 199    s200    Movie                            Koi Aap Sa
#
#                 director                                               cast  \
# 7           Haile Gerima  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8        Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9         Theodore Melfi  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12   Christian Schwochow  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24            S. Shankar  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ..                   ...                                                ...
# 191      Taylor Sheridan  Jeremy Renner, Elizabeth Olsen, Jon Bernthal, ...
# 192         Sachin Yardi  Mithun Chakraborty, Tusshar Kapoor, Anupam Khe...
# 195        Saurabh Kabra  Sanjay Dutt, Arjun Rampal, Malaika Arora, Aash...
# 198         Kemi Adetiba  Sola Sobowale, Toni Tones, Richard Mofe-Damijo...
# 199         Partho Mitra  Aftab Shivdasani, Natassha, Dipannita Sharma, ...
#
#                                                country date_added  \
# 7    United States, Ghana, Burkina Faso, United Kin...  24-Sep-21
# 8                                       United Kingdom  24-Sep-21
# 9                                        United States  24-Sep-21
# 12                             Germany, Czech Republic  23-Sep-21
# 24                                               India  21-Sep-21
# ..                                                 ...        ...
# 191              United Kingdom, Canada, United States  28-Aug-21
# 192                                              India  27-Aug-21
# 195                                              India  27-Aug-21
# 198                                            Nigeria  27-Aug-21
# 199                                              India  27-Aug-21
#
#      release_year rating   duration  \
# 7            1993  TV-MA    125 min
# 8            2021  TV-14  9 Seasons
# 9            2021  PG-13    104 min
# 12           2021  TV-MA    127 min
# 24           1998  TV-14    166 min
# ..            ...    ...        ...
# 191          2017      R    107 min
# 192          2008  TV-14    127 min
# 195          2008  TV-14    128 min
# 198          2021  TV-MA   1 Season
# 199          2006  TV-14    135 min
#
#                                              listed_in  \
# 7     Dramas, Independent Movies, International Movies
# 8                         British TV Shows, Reality TV
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# 24     Comedies, International Movies, Romantic Movies
# ..                                                 ...
# 191                         Dramas, Independent Movies
# 192  Action & Adventure, Comedies, International Mo...
# 195             Comedies, Dramas, International Movies
# 198  Crime TV Shows, International TV Shows, TV Dramas
# 199             Comedies, Dramas, International Movies
#
#                                            description
# 7    On a photo shoot in Ghana, an American model s...
# 8    A talented batch of amateur bakers face off in...
# 9    A woman adjusting to life after a loss contend...
# 12   After most of her family is murdered in a terr...
# 24   When the father of the man she loves insists t...
# ..                                                 ...
# 191  A tracker with the U.S. Fish and Wildlife Serv...
# 192  Three broke friends pose as an underworld gang...
# 195  A bank hires an enigmatic and unorthodox debt ...
# 198  Alhaja Eniola Salami starts anew and sets her ...
# 199  Star athlete Rohan has his eye on a beautiful ...
#
# [94 rows x 12 columns]

# %%
df.drop(['show_id'],axis=1, inplace=True)

# %%
df.drop(['date_added'],axis=1, inplace=True)

# %%
num = df.select_dtypes(exclude=['object'])

# %%
num
# Out:
#      release_year
# 7            1993
# 8            2021
# 9            2021
# 12           2021
# 24           1998
# ..            ...
# 191          2017
# 192          2008
# 195          2008
# 198          2021
# 199          2006
#
# [94 rows x 1 columns]

# %%
char = df.select_dtypes(include=['object'])

# %%
char
# Out:
#         type                                 title             director  \
# 7      Movie                               Sankofa         Haile Gerima
# 8    TV Show         The Great British Baking Show      Andy Devonshire
# 9      Movie                          The Starling       Theodore Melfi
# 12     Movie                          Je Suis Karl  Christian Schwochow
# 24     Movie                                 Jeans           S. Shankar
# ..       ...                                   ...                  ...
# 191    Movie                            Wind River      Taylor Sheridan
# 192    Movie                            C Kkompany         Sachin Yardi
# 195    Movie       EMI: Liya Hai To Chukana Padega        Saurabh Kabra
# 198  TV Show  King of Boys: The Return of the King         Kemi Adetiba
# 199    Movie                            Koi Aap Sa         Partho Mitra
#
#                                                   cast  \
# 7    Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8    Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9    Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12   Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24   Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ..                                                 ...
# 191  Jeremy Renner, Elizabeth Olsen, Jon Bernthal, ...
# 192  Mithun Chakraborty, Tusshar Kapoor, Anupam Khe...
# 195  Sanjay Dutt, Arjun Rampal, Malaika Arora, Aash...
# 198  Sola Sobowale, Toni Tones, Richard Mofe-Damijo...
# 199  Aftab Shivdasani, Natassha, Dipannita Sharma, ...
#
#                                                country rating   duration  \
# 7    United States, Ghana, Burkina Faso, United Kin...  TV-MA    125 min
# 8                                       United Kingdom  TV-14  9 Seasons
# 9                                        United States  PG-13    104 min
# 12                             Germany, Czech Republic  TV-MA    127 min
# 24                                               India  TV-14    166 min
# ..                                                 ...    ...        ...
# 191              United Kingdom, Canada, United States      R    107 min
# 192                                              India  TV-14    127 min
# 195                                              India  TV-14    128 min
# 198                                            Nigeria  TV-MA   1 Season
# 199                                              India  TV-14    135 min
#
#                                              listed_in  \
# 7     Dramas, Independent Movies, International Movies
# 8                         British TV Shows, Reality TV
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# 24     Comedies, International Movies, Romantic Movies
# ..                                                 ...
# 191                         Dramas, Independent Movies
# 192  Action & Adventure, Comedies, International Mo...
# 195             Comedies, Dramas, International Movies
# 198  Crime TV Shows, International TV Shows, TV Dramas
# 199             Comedies, Dramas, International Movies
#
#                                            description
# 7    On a photo shoot in Ghana, an American model s...
# 8    A talented batch of amateur bakers face off in...
# 9    A woman adjusting to life after a loss contend...
# 12   After most of her family is murdered in a terr...
# 24   When the father of the man she loves insists t...
# ..                                                 ...
# 191  A tracker with the U.S. Fish and Wildlife Serv...
# 192  Three broke friends pose as an underworld gang...
# 195  A bank hires an enigmatic and unorthodox debt ...
# 198  Alhaja Eniola Salami starts anew and sets her ...
# 199  Star athlete Rohan has his eye on a beautiful ...
#
# [94 rows x 9 columns]

# %%
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['type'] = le.fit_transform(df['type'])
df['title'] = le.fit_transform(df['title'])
df['director'] = le.fit_transform(df['director'])
df['cast'] = le.fit_transform(df['cast'])
df['country'] = le.fit_transform(df['country'])
df['rating'] = le.fit_transform(df['rating'])
df['listed_in'] = le.fit_transform(df['listed_in'])
df['description'] = le.fit_transform(df['description'])
df['duration'] = le.fit_transform(df['duration'])

# %%
df
# Out:
#      type  title  director  cast  country  release_year  rating  duration  \
# 7       0     77        20    59       25          1993       5        24
# 8       1     85         3    70       16          2021       4        44
# 9       0     89        74    71       21          2021       2         5
# 12      0     44         9    63        6          2021       5        25
# 24      0     45        59    77        9          1998       4        34
# ..    ...    ...       ...   ...      ...           ...     ...       ...
# 191     0     93        72    40       19          2017       3         8
# 192     0      9        60    73        9          2008       4        25
# 195     0     19        61    85        9          2008       4        26
# 198     1     48        30    89       12          2021       5         0
# 199     0     49        46     3        9          2006       4        28
#
#      listed_in  description
# 7           38           54
# 8           14           13
# 9           23           20
# 12          39           29
# 24          28           87
# ..         ...          ...
# 191         37           16
# 192          9           72
# 195         25            1
# 198         31           32
# 199         25           62
#
# [94 rows x 10 columns]

# %%
x = df.drop(['title'], axis=1)
y = df['title']

# %%
df['title'].value_counts()
# Out:
# title
# 77    1
# 85    1
# 89    1
# 44    1
# 45    1
#      ..
# 93    1
# 9     1
# 19    1
# 48    1
# 49    1
# Name: count, Length: 94, dtype: int64

# %%
df['title'].unique()
# Out:
# array([77, 85, 89, 44, 45, 24, 15, 72,  6, 40, 41, 42, 43, 75, 91, 35, 36,
#        37, 38, 59, 62, 63, 60, 61, 64, 65, 66, 47, 46, 67, 71, 80, 30,  4,
#         1,  5,  8, 17, 25, 32, 79,  2,  3,  7, 10, 11, 12, 13, 14, 16, 18,
#        20, 21, 22, 23, 26, 27, 28, 29, 31, 34, 39, 50, 51, 52, 53, 54, 55,
#        56, 57, 58, 68, 69, 70, 73, 74, 76, 78, 81, 82, 83, 84, 86, 87, 88,
#        92, 33,  0, 90, 93,  9, 19, 48, 49])

# %%
x
# Out:
#      type  director  cast  country  release_year  rating  duration  listed_in  \
# 7       0        20    59       25          1993       5        24         38
# 8       1         3    70       16          2021       4        44         14
# 9       0        74    71       21          2021       2         5         23
# 12      0         9    63        6          2021       5        25         39
# 24      0        59    77        9          1998       4        34         28
# ..    ...       ...   ...      ...           ...     ...       ...        ...
# 191     0        72    40       19          2017       3         8         37
# 192     0        60    73        9          2008       4        25          9
# 195     0        61    85        9          2008       4        26         25
# 198     1        30    89       12          2021       5         0         31
# 199     0        46     3        9          2006       4        28         25
#
#      description
# 7             54
# 8             13
# 9             20
# 12            29
# 24            87
# ..           ...
# 191           16
# 192           72
# 195            1
# 198           32
# 199           62
#
# [94 rows x 9 columns]

# %%
y
# Out:
# 7      77
# 8      85
# 9      89
# 12     44
# 24     45
#        ..
# 191    93
# 192     9
# 195    19
# 198    48
# 199    49
# Name: title, Length: 94, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((75, 9), (19, 9), (75,), (19,))

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=42) 
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
model.score(x_test, y_test)
# Out:
# 0.0

# %%
model.score(x_train, y_train)
# Out:
# 1.0

# %%
from sklearn.naive_bayes import GaussianNB  
model = GaussianNB()
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
model.get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
model.score(x_test, y_test)
# Out:
# 0.0

# %%
model.score(x_train, y_train )
# Out:
# 1.0

# %%
from sklearn.naive_bayes import BernoulliNB
model = BernoulliNB()
model.fit(x_train, y_train)
# Out:
# BernoulliNB()

# %%
model.score(x_test, y_test)
# Out:
# 0.0

# %%
model.score(x_train, y_train)
# Out:
# 1.0

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB() 
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
model.score(x_test, y_test)
# Out:
# 0.0

# %%
model.score(x_train, y_train)
# Out:
# 1.0
